# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagodonizetti/IHC21---eye-tracker-analyses/blob/main/COLAB_IHC_21_Fixations_analyses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fixation analyses
# ## Dataset
# **Description:** Dataset containing number of fixations by Areas of interest captured using eye tracking. They are results from field study performed at @CRECI. The study aims at supporting personalization features for people with Computer Anxiety (PwCA).
#
# **Goal:** Identify UI elements related with different levels of Computer Anxiety which may be acting as distractors and making it difficult to the users to perform the suggested tasks.

# %% [markdown]
# ### Loading the dataset

# %%
import pandas as pd
import numpy as np
import imblearn

import matplotlib.pyplot as plot
from scipy import stats
from sklearn import preprocessing
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu
from scipy.stats import shapiro
from scipy.stats import levene


#from ipyfilechooser import FileChooser
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import RandomOverSampler

from sklearn.preprocessing import MinMaxScaler
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e3fb8256-0a39-496e-a4ba-c1db47af41f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3fb8256-0a39-496e-a4ba-c1db47af41f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ### Reading data

# %%
df = pd.read_excel('eyetracker.xlsx', sheet_name='data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ae20987a6a2b> in <module>()
# ----> 1 df = pd.read_excel('eyetracker.xlsx', sheet_name='data')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# /usr/local/lib/python3.7/dist-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     114         peek = file_contents[:peeksz]
#     115     else:
# --> 116         with open(filename, "rb") as f:
#     117             peek = f.read(peeksz)
#     118     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'eyetracker.xlsx'

# %% [markdown]
# ### Shapiro-Wilk test for normality.

# %%
df2 = df.drop(columns=['CLASS'])
for col in df2:
    print ('\n',col)
    swtest, p_col = shapiro( df2[col] )
    print( 'Shapiro-Wilk (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
#  p
# Shapiro-Wilk ( p ) p-value: 0.67812
# Sample looks Gaussian (fail to reject H0)
#
#  CARS
# Shapiro-Wilk ( CARS ) p-value: 0.18381
# Sample looks Gaussian (fail to reject H0)
#
#  H-Search Box
# Shapiro-Wilk ( H-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  H-Top Menu
# Shapiro-Wilk ( H-Top Menu ) p-value: 0.00001
# Sample does not look Gaussian (reject H0)
#
#  H-Carousel
# Shapiro-Wilk ( H-Carousel ) p-value: 0.00003
# Sample does not look Gaussian (reject H0)
#
#  H-Content
# Shapiro-Wilk ( H-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Side Menu
# Shapiro-Wilk ( C-Side Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Search Box
# Shapiro-Wilk ( C-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Top Menu
# Shapiro-Wilk ( C-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Content
# Shapiro-Wilk ( C-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Search Box
# Shapiro-Wilk ( A-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Top Menu
# Shapiro-Wilk ( A-Top Menu ) p-value: 0.00627
# Sample does not look Gaussian (reject H0)
#
#  A-Description
# Shapiro-Wilk ( A-Description ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Card
# Shapiro-Wilk ( A-Card ) p-value: 0.00163
# Sample does not look Gaussian (reject H0)
#
#  A-Show Map
# Shapiro-Wilk ( A-Show Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Search Box
# Shapiro-Wilk ( U-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Top Menu
# Shapiro-Wilk ( U-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Information
# Shapiro-Wilk ( U-Information ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Show Map
# Shapiro-Wilk ( U-Show Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Carrossel
# Shapiro-Wilk ( U-Carrossel ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Content
# Shapiro-Wilk ( U-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Input Address
# Shapiro-Wilk ( M-Input Address ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Routes
# Shapiro-Wilk ( M-Routes ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Map
# Shapiro-Wilk ( M-Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Tabs
# Shapiro-Wilk ( R-Tabs ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Content
# Shapiro-Wilk ( R-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Top Menu
# Shapiro-Wilk ( R-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# **Shapiro-Wilk test results**
#
# Results show that the sample does not look Gaussian for all the AOI's tested.

# %% [markdown]
# ### **Separete groups of CA.**

# %%
df_high = df2[df2['CARS'] >= 47]
df_no = df2[df2['CARS'] < 34]
df_low = df2[df2['CARS'] >= 34]
df_low = df_low[df_low['CARS'] < 47]

# %% [markdown]
# ### Shapiro-Wilk test for normality (HIGH CA).

# %%
for col in df_high:
    print ('\n',col)
    swtest, p_col = shapiro( df[col] )
    print( 'Shapiro-Wilk (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
#  p
# Shapiro-Wilk ( p ) p-value: 0.67812
# Sample looks Gaussian (fail to reject H0)
#
#  CARS
# Shapiro-Wilk ( CARS ) p-value: 0.18381
# Sample looks Gaussian (fail to reject H0)
#
#  H-Search Box
# Shapiro-Wilk ( H-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  H-Top Menu
# Shapiro-Wilk ( H-Top Menu ) p-value: 0.00001
# Sample does not look Gaussian (reject H0)
#
#  H-Carousel
# Shapiro-Wilk ( H-Carousel ) p-value: 0.00003
# Sample does not look Gaussian (reject H0)
#
#  H-Content
# Shapiro-Wilk ( H-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Side Menu
# Shapiro-Wilk ( C-Side Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Search Box
# Shapiro-Wilk ( C-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Top Menu
# Shapiro-Wilk ( C-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Content
# Shapiro-Wilk ( C-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Search Box
# Shapiro-Wilk ( A-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Top Menu
# Shapiro-Wilk ( A-Top Menu ) p-value: 0.00627
# Sample does not look Gaussian (reject H0)
#
#  A-Description
# Shapiro-Wilk ( A-Description ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Card
# Shapiro-Wilk ( A-Card ) p-value: 0.00163
# Sample does not look Gaussian (reject H0)
#
#  A-Show Map
# Shapiro-Wilk ( A-Show Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Search Box
# Shapiro-Wilk ( U-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Top Menu
# Shapiro-Wilk ( U-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Information
# Shapiro-Wilk ( U-Information ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Show Map
# Shapiro-Wilk ( U-Show Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Carrossel
# Shapiro-Wilk ( U-Carrossel ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Content
# Shapiro-Wilk ( U-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Input Address
# Shapiro-Wilk ( M-Input Address ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Routes
# Shapiro-Wilk ( M-Routes ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Map
# Shapiro-Wilk ( M-Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Tabs
# Shapiro-Wilk ( R-Tabs ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Content
# Shapiro-Wilk ( R-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Top Menu
# Shapiro-Wilk ( R-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# **Shapiro-Wilk test results**
#
# Results show that the HIGH CA sample does not look Gaussian for all the AOI's tested.

# %% [markdown]
# ###Shapiro-Wilk test for normality (LOW CA)

# %%
for col in df_low:
    print ('\n',col)
    swtest, p_col = shapiro( df[col] )
    print( 'Shapiro-Wilk (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8ede076c8b07> in <module>()
# ----> 1 for col in df_low:
#       2     print ('\n',col)
#       3     swtest, p_col = shapiro( df[col] )
#       4     print( 'Shapiro-Wilk (', col, ') p-value: {:.5f}'.format( p_col ) )
#       5     alpha = 0.05
#
# NameError: name 'df_low' is not defined

# %% [markdown]
# **Shapiro-Wilk test results**
#
# Results show that the LOW CA sample does not look Gaussian for all the AOI's tested.

# %% [markdown]
# ### Shapiro-Wilk test for normality (No CA).

# %%
for col in df_no:
    print ('\n',col)
    swtest, p_col = shapiro( df[col] )
    print( 'Shapiro-Wilk (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print('Sample looks Gaussian (fail to reject H0)')
    else:
        print('Sample does not look Gaussian (reject H0)')
# Out:
#  p
# Shapiro-Wilk ( p ) p-value: 0.67812
# Sample looks Gaussian (fail to reject H0)
#
#  CARS
# Shapiro-Wilk ( CARS ) p-value: 0.18381
# Sample looks Gaussian (fail to reject H0)
#
#  H-Search Box
# Shapiro-Wilk ( H-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  H-Top Menu
# Shapiro-Wilk ( H-Top Menu ) p-value: 0.00001
# Sample does not look Gaussian (reject H0)
#
#  H-Carousel
# Shapiro-Wilk ( H-Carousel ) p-value: 0.00003
# Sample does not look Gaussian (reject H0)
#
#  H-Content
# Shapiro-Wilk ( H-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Side Menu
# Shapiro-Wilk ( C-Side Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Search Box
# Shapiro-Wilk ( C-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Top Menu
# Shapiro-Wilk ( C-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  C-Content
# Shapiro-Wilk ( C-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Search Box
# Shapiro-Wilk ( A-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Top Menu
# Shapiro-Wilk ( A-Top Menu ) p-value: 0.00627
# Sample does not look Gaussian (reject H0)
#
#  A-Description
# Shapiro-Wilk ( A-Description ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  A-Card
# Shapiro-Wilk ( A-Card ) p-value: 0.00163
# Sample does not look Gaussian (reject H0)
#
#  A-Show Map
# Shapiro-Wilk ( A-Show Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Search Box
# Shapiro-Wilk ( U-Search Box ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Top Menu
# Shapiro-Wilk ( U-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Information
# Shapiro-Wilk ( U-Information ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Show Map
# Shapiro-Wilk ( U-Show Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Carrossel
# Shapiro-Wilk ( U-Carrossel ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  U-Content
# Shapiro-Wilk ( U-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Input Address
# Shapiro-Wilk ( M-Input Address ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Routes
# Shapiro-Wilk ( M-Routes ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  M-Map
# Shapiro-Wilk ( M-Map ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Tabs
# Shapiro-Wilk ( R-Tabs ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Content
# Shapiro-Wilk ( R-Content ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)
#
#  R-Top Menu
# Shapiro-Wilk ( R-Top Menu ) p-value: 0.00000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# **Shapiro-Wilk test results**
#
# Results show that the NO CA sample does not look Gaussian for all the AOI's tested.

# %% [markdown]
# ### Levine test for variance between classes

# %%
for col in df2:
    print ('\n',col)
    
    #compare the variance between the three classes for the same AOI column:
    ltest, p_col = levene(df_high[col], df_low[col], df_no[col])
    
    print( 'Levene (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print('Sample seems to have the same variance (fail to reject H0)')
    else:
        print('Sample does not seem to have the same variance (reject H0)')
# Out:
#  p
# Levene ( p ) p-value: 0.39036
# Sample seems to have the same variance (fail to reject H0)
#
#  CARS
# Levene ( CARS ) p-value: 0.71668
# Sample seems to have the same variance (fail to reject H0)
#
#  H-Search Box
# Levene ( H-Search Box ) p-value: 0.83344
# Sample seems to have the same variance (fail to reject H0)
#
#  H-Top Menu
# Levene ( H-Top Menu ) p-value: 0.85114
# Sample seems to have the same variance (fail to reject H0)
#
#  H-Carousel
# Levene ( H-Carousel ) p-value: 0.48343
# Sample seems to have the same variance (fail to reject H0)
#
#  H-Content
# Levene ( H-Content ) p-value: 0.26674
# Sample seems to have the same variance (fail to reject H0)
#
#  C-Side Menu
# Levene ( C-Side Menu ) p-value: 0.36678
# Sample seems to have the same variance (fail to reject H0)
#
#  C-Search Box
# Levene ( C-Search Box ) p-value: 0.39633
# Sample seems to have the same variance (fail to reject H0)
#
#  C-Top Menu
# Levene ( C-Top Menu ) p-value: 0.03743
# Sample does not seem to have the same variance (reject H0)
#
#  C-Content
# Levene ( C-Content ) p-value: 0.45804
# Sample seems to have the same variance (fail to reject H0)
#
#  A-Search Box
# Levene ( A-Search Box ) p-value: 0.08590
# Sample seems to have the same variance (fail to reject H0)
#
#  A-Top Menu
# Levene ( A-Top Menu ) p-value: 0.61823
# Sample seems to have the same variance (fail to reject H0)
#
#  A-Description
# Levene ( A-Description ) p-value: 0.91044
# Sample seems to have the same variance (fail to reject H0)
#
#  A-Card
# Levene ( A-Card ) p-value: 0.93055
# Sample seems to have the same variance (fail to reject H0)
#
#  A-Show Map
# Levene ( A-Show Map ) p-value: 0.35460
# Sample seems to have the same variance (fail to reject H0)
#
#  U-Search Box
# Levene ( U-Search Box ) p-value: 0.54638
# Sample seems to have the same variance (fail to reject H0)
#
#  U-Top Menu
# Levene ( U-Top Menu ) p-value: 0.78044
# Sample seems to have the same variance (fail to reject H0)
#
#  U-Information
# Levene ( U-Information ) p-value: 0.76047
# Sample seems to have the same variance (fail to reject H0)
#
#  U-Show Map
# Levene ( U-Show Map ) p-value: 0.67234
# Sample seems to have the same variance (fail to reject H0)
#
#  U-Carrossel
# Levene ( U-Carrossel ) p-value: 0.94858
# Sample seems to have the same variance (fail to reject H0)
#
#  U-Content
# Levene ( U-Content ) p-value: 0.14343
# Sample seems to have the same variance (fail to reject H0)
#
#  M-Input Address
# Levene ( M-Input Address ) p-value: 0.20512
# Sample seems to have the same variance (fail to reject H0)
#
#  M-Routes
# Levene ( M-Routes ) p-value: 0.00601
# Sample does not seem to have the same variance (reject H0)
#
#  M-Map
# Levene ( M-Map ) p-value: 0.21881
# Sample seems to have the same variance (fail to reject H0)
#
#  R-Tabs
# Levene ( R-Tabs ) p-value: 0.30094
# Sample seems to have the same variance (fail to reject H0)
#
#  R-Content
# Levene ( R-Content ) p-value: 0.40597
# Sample seems to have the same variance (fail to reject H0)
#
#  R-Top Menu
# Levene ( R-Top Menu ) p-value: 0.59301
# Sample seems to have the same variance (fail to reject H0)

# %% [markdown]
# **Levene test results**
#
# Levene test results show that sample does not seem to have the same variance for:
#
#
# *   C-Top Menu with *p-value = 0.03743*
# *   M-Routes with *p-value = 0.00601*

# %% [markdown]
# ### Kruskal-Wallis H-test

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between the three classes for the same AOI column:
    ktest, p_col = stats.kruskal(df_high[col], df_low[col], df_no[col])
    
    print( 'kruskal (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# kruskal ( p ) p-value: 0.13731
#
#
#  CARS
# kruskal ( CARS ) p-value: 0.00001
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# kruskal ( H-Search Box ) p-value: 0.90599
#
#
#  H-Top Menu
# kruskal ( H-Top Menu ) p-value: 0.52909
#
#
#  H-Carousel
# kruskal ( H-Carousel ) p-value: 0.37048
#
#
#  H-Content
# kruskal ( H-Content ) p-value: 0.30300
#
#
#  C-Side Menu
# kruskal ( C-Side Menu ) p-value: 0.42768
#
#
#  C-Search Box
# kruskal ( C-Search Box ) p-value: 0.33492
#
#
#  C-Top Menu
# kruskal ( C-Top Menu ) p-value: 0.00633
# Sample does not seem to have the same distribution (reject H0)
#
#  C-Content
# kruskal ( C-Content ) p-value: 0.10733
#
#
#  A-Search Box
# kruskal ( A-Search Box ) p-value: 0.37737
#
#
#  A-Top Menu
# kruskal ( A-Top Menu ) p-value: 0.88359
#
#
#  A-Description
# kruskal ( A-Description ) p-value: 0.14202
#
#
#  A-Card
# kruskal ( A-Card ) p-value: 0.19452
#
#
#  A-Show Map
# kruskal ( A-Show Map ) p-value: 0.31140
#
#
#  U-Search Box
# kruskal ( U-Search Box ) p-value: 0.49364
#
#
#  U-Top Menu
# kruskal ( U-Top Menu ) p-value: 0.73435
#
#
#  U-Information
# kruskal ( U-Information ) p-value: 0.53970
#
#
#  U-Show Map
# kruskal ( U-Show Map ) p-value: 0.45952
#
#
#  U-Carrossel
# kruskal ( U-Carrossel ) p-value: 0.52297
#
#
#  U-Content
# kruskal ( U-Content ) p-value: 0.16151
#
#
#  M-Input Address
# kruskal ( M-Input Address ) p-value: 0.11324
#
#
#  M-Routes
# kruskal ( M-Routes ) p-value: 0.13597
#
#
#  M-Map
# kruskal ( M-Map ) p-value: 0.11370
#
#
#  R-Tabs
# kruskal ( R-Tabs ) p-value: 0.22233
#
#
#  R-Content
# kruskal ( R-Content ) p-value: 0.21400
#
#
#  R-Top Menu
# kruskal ( R-Top Menu ) p-value: 0.55060

# %% [markdown]
# **Kruskal-Wallis H Test results**
#
# kruskal result for the three classes shows that the sample does not seem to have the same distribution just for the **C-Top** Menu with *p-value = 0.00633*

# %% [markdown]
# ### **Kruskal-Wallis H Test** for HIGH CA and Low CA

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between the three classes for the same AOI column:
    ktest, p_col = stats.kruskal(df_high[col], df_low[col])
    
    print( 'kruskal (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# kruskal ( p ) p-value: 0.10532
#
#
#  CARS
# kruskal ( CARS ) p-value: 0.00010
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# kruskal ( H-Search Box ) p-value: 0.95902
#
#
#  H-Top Menu
# kruskal ( H-Top Menu ) p-value: 0.28833
#
#
#  H-Carousel
# kruskal ( H-Carousel ) p-value: 0.22944
#
#
#  H-Content
# kruskal ( H-Content ) p-value: 0.11844
#
#
#  C-Side Menu
# kruskal ( C-Side Menu ) p-value: 0.17578
#
#
#  C-Search Box
# kruskal ( C-Search Box ) p-value: 0.12854
#
#
#  C-Top Menu
# kruskal ( C-Top Menu ) p-value: 0.00233
# Sample does not seem to have the same distribution (reject H0)
#
#  C-Content
# kruskal ( C-Content ) p-value: 0.03970
# Sample does not seem to have the same distribution (reject H0)
#
#  A-Search Box
# kruskal ( A-Search Box ) p-value: 0.94485
#
#
#  A-Top Menu
# kruskal ( A-Top Menu ) p-value: 0.77735
#
#
#  A-Description
# kruskal ( A-Description ) p-value: 0.08672
#
#
#  A-Card
# kruskal ( A-Card ) p-value: 0.06059
#
#
#  A-Show Map
# kruskal ( A-Show Map ) p-value: 0.92948
#
#
#  U-Search Box
# kruskal ( U-Search Box ) p-value: 0.29427
#
#
#  U-Top Menu
# kruskal ( U-Top Menu ) p-value: 0.54021
#
#
#  U-Information
# kruskal ( U-Information ) p-value: 0.45002
#
#
#  U-Show Map
# kruskal ( U-Show Map ) p-value: 0.56311
#
#
#  U-Carrossel
# kruskal ( U-Carrossel ) p-value: 0.33056
#
#
#  U-Content
# kruskal ( U-Content ) p-value: 0.18184
#
#
#  M-Input Address
# kruskal ( M-Input Address ) p-value: 0.79115
#
#
#  M-Routes
# kruskal ( M-Routes ) p-value: 0.77741
#
#
#  M-Map
# kruskal ( M-Map ) p-value: 0.51915
#
#
#  R-Tabs
# kruskal ( R-Tabs ) p-value: 0.12854
#
#
#  R-Content
# kruskal ( R-Content ) p-value: 0.12854
#
#
#  R-Top Menu
# kruskal ( R-Top Menu ) p-value: 0.48777

# %% [markdown]
#  Kruskal-Wallis H test results for **High CA and Low CA** show that sample does not seem to have the same distribution for:
#
# *   C-Top Menu with *p-value = 0.00233*
# *   C-Content with *p-value = 0.03970*

# %% [markdown]
# ### **Kruskal-Wallis H Test** for High CA and No CA

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between the three classes for the same AOI column:
    ktest, p_col = stats.kruskal(df_high[col], df_no[col])
    
    print( 'kruskal (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# kruskal ( p ) p-value: 0.75126
#
#
#  CARS
# kruskal ( CARS ) p-value: 0.00048
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# kruskal ( H-Search Box ) p-value: 0.70911
#
#
#  H-Top Menu
# kruskal ( H-Top Menu ) p-value: 0.46480
#
#
#  H-Carousel
# kruskal ( H-Carousel ) p-value: 0.25214
#
#
#  H-Content
# kruskal ( H-Content ) p-value: 0.48319
#
#
#  C-Side Menu
# kruskal ( C-Side Menu ) p-value: 1.00000
#
#
#  C-Search Box
# kruskal ( C-Search Box ) p-value: 0.21000
#
#
#  C-Top Menu
# kruskal ( C-Top Menu ) p-value: 0.06627
#
#
#  C-Content
# kruskal ( C-Content ) p-value: 0.92642
#
#
#  A-Search Box
# kruskal ( A-Search Box ) p-value: 0.23605
#
#
#  A-Top Menu
# kruskal ( A-Top Menu ) p-value: 0.89116
#
#
#  A-Description
# kruskal ( A-Description ) p-value: 0.10720
#
#
#  A-Card
# kruskal ( A-Card ) p-value: 0.40965
#
#
#  A-Show Map
# kruskal ( A-Show Map ) p-value: 0.23365
#
#
#  U-Search Box
# kruskal ( U-Search Box ) p-value: 0.21000
#
#
#  U-Top Menu
# kruskal ( U-Top Menu ) p-value: 0.83437
#
#
#  U-Information
# kruskal ( U-Information ) p-value: 0.57577
#
#
#  U-Show Map
# kruskal ( U-Show Map ) p-value: 0.42503
#
#
#  U-Carrossel
# kruskal ( U-Carrossel ) p-value: 0.88900
#
#
#  U-Content
# kruskal ( U-Content ) p-value: 0.42503
#
#
#  M-Input Address
# kruskal ( M-Input Address ) p-value: 0.06586
#
#
#  M-Routes
# kruskal ( M-Routes ) p-value: 0.11033
#
#
#  M-Map
# kruskal ( M-Map ) p-value: 0.08187
#
#
#  R-Tabs
# kruskal ( R-Tabs ) p-value: 0.06812
#
#
#  R-Content
# kruskal ( R-Content ) p-value: 0.06812
#
#
#  R-Top Menu
# kruskal ( R-Top Menu ) p-value: 0.26417

# %% [markdown]
#  Kruskal-Wallis H test results for **High CA and No CA** show that sample seem to have the same distribution.

# %% [markdown]
# ### **Kruskal-Wallis H** Test for Low CA and No CA

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between the three classes for the same AOI column:
    ktest, p_col = stats.kruskal(df_low[col], df_no[col])
    
    print( 'kruskal (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# kruskal ( p ) p-value: 0.07898
#
#
#  CARS
# kruskal ( CARS ) p-value: 0.00061
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# kruskal ( H-Search Box ) p-value: 0.69405
#
#
#  H-Top Menu
# kruskal ( H-Top Menu ) p-value: 0.73141
#
#
#  H-Carousel
# kruskal ( H-Carousel ) p-value: 0.69592
#
#
#  H-Content
# kruskal ( H-Content ) p-value: 0.53615
#
#
#  C-Side Menu
# kruskal ( C-Side Menu ) p-value: 0.45837
#
#
#  C-Search Box
# kruskal ( C-Search Box ) p-value: 0.82557
#
#
#  C-Top Menu
# kruskal ( C-Top Menu ) p-value: 0.13707
#
#
#  C-Content
# kruskal ( C-Content ) p-value: 0.15552
#
#
#  A-Search Box
# kruskal ( A-Search Box ) p-value: 0.27115
#
#
#  A-Top Menu
# kruskal ( A-Top Menu ) p-value: 0.58984
#
#
#  A-Description
# kruskal ( A-Description ) p-value: 0.80643
#
#
#  A-Card
# kruskal ( A-Card ) p-value: 0.58892
#
#
#  A-Show Map
# kruskal ( A-Show Map ) p-value: 0.15454
#
#
#  U-Search Box
# kruskal ( U-Search Box ) p-value: 0.86168
#
#
#  U-Top Menu
# kruskal ( U-Top Menu ) p-value: 0.51207
#
#
#  U-Information
# kruskal ( U-Information ) p-value: 0.33222
#
#
#  U-Show Map
# kruskal ( U-Show Map ) p-value: 0.22260
#
#
#  U-Carrossel
# kruskal ( U-Carrossel ) p-value: 0.39619
#
#
#  U-Content
# kruskal ( U-Content ) p-value: 0.12342
#
#
#  M-Input Address
# kruskal ( M-Input Address ) p-value: 0.09089
#
#
#  M-Routes
# kruskal ( M-Routes ) p-value: 0.07649
#
#
#  M-Map
# kruskal ( M-Map ) p-value: 0.06873
#
#
#  R-Tabs
# kruskal ( R-Tabs ) p-value: 0.84390
#
#
#  R-Content
# kruskal ( R-Content ) p-value: 0.74278
#
#
#  R-Top Menu
# kruskal ( R-Top Menu ) p-value: 0.69405

# %% [markdown]
# Kruskal-Wallis H test results for **Low CA and No CA** show that sample seem to have the same distribution.
#
#
# ---

# %% [markdown]
# ### Mann-Whitney U Test
#
#
#
#
# *   **High CA x Low CA**

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between High CA and Low CA classes for the same AOI column:
    mtest, p_col = stats.mannwhitneyu(df_high[col], df_low[col])
    
    print( 'Mann-Whitney U Test (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# Mann-Whitney U Test ( p ) p-value: 0.05655
#
#
#  CARS
# Mann-Whitney U Test ( CARS ) p-value: 0.00006
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# Mann-Whitney U Test ( H-Search Box ) p-value: 0.50000
#
#
#  H-Top Menu
# Mann-Whitney U Test ( H-Top Menu ) p-value: 0.15235
#
#
#  H-Carousel
# Mann-Whitney U Test ( H-Carousel ) p-value: 0.12172
#
#
#  H-Content
# Mann-Whitney U Test ( H-Content ) p-value: 0.06397
#
#
#  C-Side Menu
# Mann-Whitney U Test ( C-Side Menu ) p-value: 0.09371
#
#
#  C-Search Box
# Mann-Whitney U Test ( C-Search Box ) p-value: 0.07342
#
#
#  C-Top Menu
# Mann-Whitney U Test ( C-Top Menu ) p-value: 0.00132
# Sample does not seem to have the same distribution (reject H0)
#
#  C-Content
# Mann-Whitney U Test ( C-Content ) p-value: 0.02162
# Sample does not seem to have the same distribution (reject H0)
#
#  A-Search Box
# Mann-Whitney U Test ( A-Search Box ) p-value: 0.50000
#
#
#  A-Top Menu
# Mann-Whitney U Test ( A-Top Menu ) p-value: 0.40229
#
#
#  A-Description
# Mann-Whitney U Test ( A-Description ) p-value: 0.04674
# Sample does not seem to have the same distribution (reject H0)
#
#  A-Card
# Mann-Whitney U Test ( A-Card ) p-value: 0.03281
# Sample does not seem to have the same distribution (reject H0)
#
#  A-Show Map
# Mann-Whitney U Test ( A-Show Map ) p-value: 0.48235
#
#
#  U-Search Box
# Mann-Whitney U Test ( U-Search Box ) p-value: 0.17018
#
#
#  U-Top Menu
# Mann-Whitney U Test ( U-Top Menu ) p-value: 0.28591
#
#
#  U-Information
# Mann-Whitney U Test ( U-Information ) p-value: 0.23779
#
#
#  U-Show Map
# Mann-Whitney U Test ( U-Show Map ) p-value: 0.30139
#
#
#  U-Carrossel
# Mann-Whitney U Test ( U-Carrossel ) p-value: 0.17650
#
#
#  U-Content
# Mann-Whitney U Test ( U-Content ) p-value: 0.09961
#
#
#  M-Input Address
# Mann-Whitney U Test ( M-Input Address ) p-value: 0.41267
#
#
#  M-Routes
# Mann-Whitney U Test ( M-Routes ) p-value: 0.40688
#
#
#  M-Map
# Mann-Whitney U Test ( M-Map ) p-value: 0.27280
#
#
#  R-Tabs
# Mann-Whitney U Test ( R-Tabs ) p-value: 0.07342
#
#
#  R-Content
# Mann-Whitney U Test ( R-Content ) p-value: 0.07342
#
#
#  R-Top Menu
# Mann-Whitney U Test ( R-Top Menu ) p-value: 0.26237

# %% [markdown]
# **Mann-Whitney U Test** results for **High CA x Low CA** show that the Sample does not seem to have the same distribution for:
#
# *   C-Top Menu with *p-value: 0.00132*
# *   C-Content with *p-value: 0.02162*
# *   A-Description with *p-value: 0.04674*
# *   A-Card with *p-value: 0.03281*
#
#
# ---

# %% [markdown]
# *   **High CA X No CA**

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between High CA and No CA classes for the same AOI column:
    mtest, p_col = stats.mannwhitneyu(df_high[col], df_no[col])
    
    print( 'Mann-Whitney U Test (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# Mann-Whitney U Test ( p ) p-value: 0.39293
#
#
#  CARS
# Mann-Whitney U Test ( CARS ) p-value: 0.00028
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# Mann-Whitney U Test ( H-Search Box ) p-value: 0.37795
#
#
#  H-Top Menu
# Mann-Whitney U Test ( H-Top Menu ) p-value: 0.24658
#
#
#  H-Carousel
# Mann-Whitney U Test ( H-Carousel ) p-value: 0.13581
#
#
#  H-Content
# Mann-Whitney U Test ( H-Content ) p-value: 0.25874
#
#
#  C-Side Menu
# Mann-Whitney U Test ( C-Side Menu ) p-value: 0.48138
#
#
#  C-Search Box
# Mann-Whitney U Test ( C-Search Box ) p-value: 0.12723
#
#
#  C-Top Menu
# Mann-Whitney U Test ( C-Top Menu ) p-value: 0.03733
# Sample does not seem to have the same distribution (reject H0)
#
#  C-Content
# Mann-Whitney U Test ( C-Content ) p-value: 0.48159
#
#
#  A-Search Box
# Mann-Whitney U Test ( A-Search Box ) p-value: 0.13238
#
#
#  A-Top Menu
# Mann-Whitney U Test ( A-Top Menu ) p-value: 0.46366
#
#
#  A-Description
# Mann-Whitney U Test ( A-Description ) p-value: 0.05881
#
#
#  A-Card
# Mann-Whitney U Test ( A-Card ) p-value: 0.21808
#
#
#  A-Show Map
# Mann-Whitney U Test ( A-Show Map ) p-value: 0.12730
#
#
#  U-Search Box
# Mann-Whitney U Test ( U-Search Box ) p-value: 0.12723
#
#
#  U-Top Menu
# Mann-Whitney U Test ( U-Top Menu ) p-value: 0.44457
#
#
#  U-Information
# Mann-Whitney U Test ( U-Information ) p-value: 0.30945
#
#
#  U-Show Map
# Mann-Whitney U Test ( U-Show Map ) p-value: 0.24706
#
#
#  U-Carrossel
# Mann-Whitney U Test ( U-Carrossel ) p-value: 0.47218
#
#
#  U-Content
# Mann-Whitney U Test ( U-Content ) p-value: 0.24706
#
#
#  M-Input Address
# Mann-Whitney U Test ( M-Input Address ) p-value: 0.03675
# Sample does not seem to have the same distribution (reject H0)
#
#  M-Routes
# Mann-Whitney U Test ( M-Routes ) p-value: 0.06115
#
#
#  M-Map
# Mann-Whitney U Test ( M-Map ) p-value: 0.04549
# Sample does not seem to have the same distribution (reject H0)
#
#  R-Tabs
# Mann-Whitney U Test ( R-Tabs ) p-value: 0.04082
# Sample does not seem to have the same distribution (reject H0)
#
#  R-Content
# Mann-Whitney U Test ( R-Content ) p-value: 0.04082
# Sample does not seem to have the same distribution (reject H0)
#
#  R-Top Menu
# Mann-Whitney U Test ( R-Top Menu ) p-value: 0.14760

# %% [markdown]
# **Mann-Whitney U Test** results for **High CA x No CA** show that the sample does not seem to have the same distribution for:
#
# *  C-Top Menu with *p-value: 0.03733*
# *  M-Input Address with *p-value: 0.03675*
# *  M-Map with *p-value: 0.04549*
# *  R-Tabs with *p-value: 0.04082*
# *  R-Content with *p-value: 0.04082*
#
#
# ---

# %% [markdown]
# * **Low CA x No CA**

# %%
for col in df2:
    print ('\n',col)
    
    #compare the distribution between Low CA and No CA classes for the same AOI column:
    mtest, p_col = stats.mannwhitneyu(df_low[col], df_no[col])
    
    print( 'Mann-Whitney U Test (', col, ') p-value: {:.5f}'.format( p_col ) ) 
    alpha = 0.05
    if p_col > alpha:
        print("")#print('Sample seems to have the same distribution (fail to reject H0)')
    else:
        print('Sample does not seem to have the same distribution (reject H0)')
# Out:
#  p
# Mann-Whitney U Test ( p ) p-value: 0.04383
# Sample does not seem to have the same distribution (reject H0)
#
#  CARS
# Mann-Whitney U Test ( CARS ) p-value: 0.00036
# Sample does not seem to have the same distribution (reject H0)
#
#  H-Search Box
# Mann-Whitney U Test ( H-Search Box ) p-value: 0.37153
#
#
#  H-Top Menu
# Mann-Whitney U Test ( H-Top Menu ) p-value: 0.38430
#
#
#  H-Carousel
# Mann-Whitney U Test ( H-Carousel ) p-value: 0.36618
#
#
#  H-Content
# Mann-Whitney U Test ( H-Content ) p-value: 0.28533
#
#
#  C-Side Menu
# Mann-Whitney U Test ( C-Side Menu ) p-value: 0.24444
#
#
#  C-Search Box
# Mann-Whitney U Test ( C-Search Box ) p-value: 0.44160
#
#
#  C-Top Menu
# Mann-Whitney U Test ( C-Top Menu ) p-value: 0.07532
#
#
#  C-Content
# Mann-Whitney U Test ( C-Content ) p-value: 0.08514
#
#
#  A-Search Box
# Mann-Whitney U Test ( A-Search Box ) p-value: 0.15220
#
#
#  A-Top Menu
# Mann-Whitney U Test ( A-Top Menu ) p-value: 0.31205
#
#
#  A-Description
# Mann-Whitney U Test ( A-Description ) p-value: 0.42230
#
#
#  A-Card
# Mann-Whitney U Test ( A-Card ) p-value: 0.31162
#
#
#  A-Show Map
# Mann-Whitney U Test ( A-Show Map ) p-value: 0.08551
#
#
#  U-Search Box
# Mann-Whitney U Test ( U-Search Box ) p-value: 0.46529
#
#
#  U-Top Menu
# Mann-Whitney U Test ( U-Top Menu ) p-value: 0.27758
#
#
#  U-Information
# Mann-Whitney U Test ( U-Information ) p-value: 0.18166
#
#
#  U-Show Map
# Mann-Whitney U Test ( U-Show Map ) p-value: 0.12871
#
#
#  U-Carrossel
# Mann-Whitney U Test ( U-Carrossel ) p-value: 0.21540
#
#
#  U-Content
# Mann-Whitney U Test ( U-Content ) p-value: 0.07116
#
#
#  M-Input Address
# Mann-Whitney U Test ( M-Input Address ) p-value: 0.05073
#
#
#  M-Routes
# Mann-Whitney U Test ( M-Routes ) p-value: 0.04324
# Sample does not seem to have the same distribution (reject H0)
#
#  M-Map
# Mann-Whitney U Test ( M-Map ) p-value: 0.03839
# Sample does not seem to have the same distribution (reject H0)
#
#  R-Tabs
# Mann-Whitney U Test ( R-Tabs ) p-value: 0.44778
#
#
#  R-Content
# Mann-Whitney U Test ( R-Content ) p-value: 0.39645
#
#
#  R-Top Menu
# Mann-Whitney U Test ( R-Top Menu ) p-value: 0.37153

# %% [markdown]
# **Mann-Whitney U Test** results for **Low CA x No CA** show that the sample does not seem to have the same distribution for:
#
# *  M-Routes with *p-value: 0.04324*
# *  M-Map Address with *p-value: 0.03839*
#
#
# ---
